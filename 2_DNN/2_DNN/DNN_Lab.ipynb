# %% [markdown]
# # Deep Neural Networks Laboration
#
# ### **Quick introduction to Jupiter notebooks**
# * Each cell in this notebook contains either code or text.
# * You can run a cell by pressing Ctrl-Enter, or run and advance to the next cell with Shift-Enter.
# * Code cells will print their output, including images, below the cell. Rerunning it deletes the previous output, so be careful if you want to save some results.
# * You don't have to rerun all cells to test changes, just rerun the cell you have made changes to. Some exceptions might apply, for example if you overwrite variables from previous cells, but in general this will work.
# * If all else fails, use the "Kernel" menu and select "Restart Kernel and Clear All Output". You can also use this menu to run all cells.
# * A useful debug tool is the console. You can right-click anywhere in the notebook and select "New console for notebook". This opens a python console which shares the environment with the notebook, which let's you easily print variables or test commands.

# %%
# Setups
# Automatically reload modules when changed
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### **Your task**
# Your task is to make a DNN that can classify benign or malicious networks attacks using the Mirai dataset (see below).
#
# **You need to answer all the questions in the notebook.** Also, for all classification tasks that you will explore, you should always answer these two questions:
# - How good classification accuracy can a naive classifier obtain? The naive classifier will assume that all examples belong to one class.
# - What is random chance classification accuracy if you randomly guess the label of each (test) example? For a balanced dataset and binary classification this is easy (50%), but in many cases it is more complicated and a Monte Carlo simulation may be required to estimate random chance accuracy.
#
# If your classifier cannot perform better than a naive classifier or a random classifier, you are doing something wrong.
#
# If the training is too slow on your own computer, use the smaller datasets (*half or *quarter).
#
# Dense networks are not optimal for tabular datasets like the one used here, but here the main goal is to explore and get a a hands-on experience with deep learning.

# %% [markdown]
# # Part 1: The Dataset #
#
# Data used in this laboration are from the [Kitsune Network Attack Datase](https://archive.ics.uci.edu/ml/datasets/Kitsune+Network+Attack+Dataset). We will focus on the 'Mirai' part of the dataset. Your task is to make a DNN that can classify if each attack is benign or malicious. The dataset has 116 covariates, but to make it a bit more difficult we will remove the first 24 covariates.
#
# ### **1.1 Load the data**
# Complete and run the following cell to to load the the `Mirai_data.npy` and the `Mirai_labels.npy` files and remove the first 24 covariances to make the classification task harder.

# %%
import os
from numpy import genfromtxt # ! Not needed if you load data from numpy arrays !
import numpy as np

# Load data from numpy arrays, choose reduced files if the training takes too long
# Load the dataset
X = np.load('Mirai_data.npy')
Y = np.load('Mirai_labels.npy') 

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# Remove the first 24 covariates (columns)
X = X[:, 24:]
Y = Y

# Print the size of the covariates and labels

# ============================================

# %% [markdown]
# ### **1.2 Explore the data (NaNs)**
# It is common to have NaNs (not a number) in the data, lets check for it.

# %%
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# It is common to have NaNs in the data, lets check for it. Hint: np.isnan()
# Fist check for NaNs in the data and then in the labels
print(np.isnan(Y).sum())
# Print the number of NaNs in the covariates
np.isnan(X).sum()


# ============================================

# %% [markdown]
# ### **1.3 Data preprocessing: normalization**

# %%
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# Convert covariates to floats
X = X.astype(float)

# Convert labels to integers
Y = Y.astype(int)


# Remove mean of each covariate (column)
# data is skewed so using robust scaling
# Divide each covariate (column) by its standard deviation


def compute_robust_params(X):
    # Calculate across columns (axis=0)
    q25, M, q75 = np.percentile(X, [25, 50, 75], axis=0)
    IQR = q75 - q25
    
    # 1.349 is to make it equivalent to z score under normality https://en.wikipedia.org/wiki/Interquartile_range
    # The result of these lines is if data is the same between 25th and 75th percentile we set most data to 0
    is_zero = np.isclose(IQR, 0, atol=1e-8)
    IQR = np.where(is_zero, 1.349, IQR)
    sd = IQR / 1.349
    
    return M, sd


def apply_robust_scaling(X, M, sd, clipping = 5):
    standardized_data = (X - M) / sd

    # Clipping extreme values to 5 and -5, motivation: outside 5 sigma is extreme values. Effect is that gradient essentially get weighted.
    standardized_data[standardized_data > clipping] = clipping
    standardized_data[standardized_data < -clipping] = -clipping
    return standardized_data

# computing location and scale after splitting the data


# ============================================

# %%
compute_robust_params(X[:, 11:25])

# %% [markdown]
# ### **1.4 Data split**
# Use the first 70% of the dataset for training, leave the other 30% for validation and test, call the variables:
# - `Xtrain` and `Ytrain`  (70% of the dataset)
# - `Xtemp` and `Ytemp`  (30% of the dataset)
#
# We use a function from scikit learn (see the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) for more details)

# %%
from sklearn.model_selection import train_test_split

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# split the original dataset into 70% Training and 30% Temp
np.random.seed(123)
Xtrain, Xtemp, Ytrain, Ytemp = train_test_split(X, Y, test_size=0.3)

mu, sd = compute_robust_params(Xtrain)
Xtrain = apply_robust_scaling(Xtrain, mu, sd)


# Print the number of examples of each class, for the training data and the remaining 30%
print(np.unique(Ytrain, return_counts = True), np.unique(Ytemp, return_counts = True))

# ============================================

print('Xtrain has size {}.'.format(Xtrain.shape))
print('Ytrain has size {}.'.format(Ytrain.shape))

print('Xtemp has size {}.'.format(Xtemp.shape))
print('Ytemp has size {}.'.format(Ytemp.shape))

# %% [markdown]
# Now split your non-training data (`Xtemp`, `Ytemp`) into 50% validation (`Xval`, `Yval`) and 50% testing (`Xtest`, `Ytest`), we use a function from scikit learn. In total this gives us 70% for training, 15% for validation, 15% for test.

# %%
from sklearn.model_selection import train_test_split

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# split the remaining 30% into 50% Validation and 50% Test


Xval, Xtest, Yval, Ytest = train_test_split(Xtemp, Ytemp, test_size=0.5)

Xval = apply_robust_scaling(Xval, mu, sd)
Xtest = apply_robust_scaling(Xtest, mu, sd)

# ============================================

print(f'The validation set has size {Xval.shape[0]}')
print(f'The test set has size {Xtest.shape[0]}')

# %%
compute_robust_params(Xval)

# %% [markdown]
# #### **<span style="color:red">Questions</span>**
# 1. Do all variables (`Xtrain`,`Ytrain`), (`Xval`,`Yval`), (`Xtest`,`Ytest`) have the shape that you expect?
# 2. Given the number of examples from each class, how high classification performance can a naive classifier obtain? The naive classifier will assume that all examples belong to one class. Note: you do not need to make a naive classifier, this is a theoretical question, just to understand how good performance we can obtain by guessing that all examples belong to one class.
#
# Note, that if your classifier cannot perform better than a naive classifier or a random classifier, you are doing something wrong.
#
#
# #### **<span style="color:green">Answer</span>**
# 1. Yes n= 764137 and they have 70/15/15% of this.
# 2. A naive classifier will have 449748/534895 = 84% accuracy

# %%
import os
import warnings

# Ignore FutureWarning from numpy
warnings.simplefilter(action='ignore', category=FutureWarning)

import tensorflow as tf

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
 
# The GPU id to use, usually either "0" or "1";
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# This sets the GPU to allocate memory only as needed
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) != 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True) 
else:
    print('No GPU available.')
# Out:
# No GPU available.

# %% [markdown]
# # Part 2: DNN classification
# In this next section you will define utilities for building the deep learning networks that will be used later and for visualizing the model training. You will also train several model experimenting with different model architecture configurations and methods for model regularization.
#
# ### **2.1 Build DNN model**
# Implement the `build_DNN` and `plot_results` functions in the `utilities.py` file. Note that for the changes in the `utilities.py` definitions to be visible by the notebook, you need to save the file.
#
# Here are some relevant functions that you should use in `build_DNN`. For a complete list of functions and their definitions see the [keras documentation](https://keras.io/api/):
#
# - `model.add()`, adds a layer to the network;
# - `Dense()`, a dense network layer. See the [documentation](https://keras.io/api/layers/core_layers/dense/) what are the input options and outputs of the `Dense()` function.
# - `model.compile()`, compiles the model. You can set the input metrics=['accuracy'] to print the classification accuracy during the training.
# - cost and loss functions: check the [documentation](https://keras.io/losses/) and chose a loss function for binary classification.
#
# To get more information in model [compile](https://keras.io/api/models/model_training_apis/#compile-method), [training](https://keras.io/api/models/model_training_apis/#fit-method) and [evaluation](https://keras.io/api/models/model_training_apis/#evaluate-method) see the relevant documentation.
#
# After defining the`build_DNN` function use it to create the your first DNN classifier. Start with a simple network with 2 dense layers (with 20 nodes each), using sigmoid activation functions. The final dense layer should have a single node and a sigmoid activation function. We start with the SGD optimizer.
#
# Make sure that the last layer always has a sigmoid activation function (why?).

# %%
from utilities import build_DNN, plot_results
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# import a suitable loss function from keras.losses and use as input to the build_DNN function.

# importing focal binary cross entropy as the classes are 16/84%, 0/1
# https://arxiv.org/pdf/1708.02002

from tf_keras.losses import BinaryFocalCrossentropy

# Build a DNN model following the specifications above
model = build_DNN((92,), 2, 20, tf.keras.losses.BinaryFocalCrossentropy(), act_fun='sigmoid', optimizer ='sgd')



# ============================================
# Out:
# WARNING:tensorflow:From c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
# 2026-02-27 13:36:10,598	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2026-02-27 13:36:11,310	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# WARNING:tensorflow:From c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# ### **2.2 Train DNN model**
#
# Time to train the DNN!
# Start simple with 2 hidden layers with 20 nodes each.
#
# Build set the different hyper-parameters, build the model and run the training. Use the following training and hyper-parameters:
# - `batch_size=20`
# - `epochs=20`
# - `learning_rate=0.1`
#
# Make sure that you are using learning rate 0.1 !

# %% [markdown]
# ### 2 hidden layers with 20 nodes each

# %%
# Setup some training and hyper-parameters
# I am changing the batch_size as it is way to slow at 20
batch_size = 100
epochs = 20

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# Specify the learning rate, the input shape and the loss function
learning_rate = 0.1
input_shape = (92,)
# Gamma is 0 then we get binarycross
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 0)

# Build the model
np.random.seed(123)
model1 = build_DNN(input_shape, 2, 20, loss, act_fun='sigmoid', optimizer='sgd', learning_rate=learning_rate, print_summary=True)

# Train the model, provide training data and validation data
history1 = model1.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size)
# ============================================

# %%
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# Evaluate the model on the test data
score = model1.evaluate(Xtest, Ytest, batch_size = 10000)

# ============================================

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])

# %%
from utilities import plot_results

# Plot the history from the training run
plot_results(history1)

# %%
print(np.bincount(Ytrain))
print(np.bincount(Yval))
print(np.bincount(Ytest))

# %% [markdown]
# #### **<span style="color:red">Questions</span>**
#
# 3. What happens if you add several Dense layers without specifying the activation function?
#
# 4. How are the weights in each dense layer initialized as default? How are the bias weights initialized?
#
# #### **<span style="color:green">Answers</span>**
# 3. It will be like logistic regression, sigmoid at the end and linear layers at the start.
# 4. Weights are initialized via glorot uniform initialization according to Keras' documenation. Biases are initizalized to 0.

# %% [markdown]
# ### **2.2 Adressing class imbalance**
#
# This dataset is rather unbalanced with the majority of the samples belonging to class=1. We need to define class weights so that the training pays more attention to the class with fewer samples. We use the [`compute_class_weight`](https://scikit-learn.org/stable/modules/generated/sklearn.utils.class_weight.compute_class_weight.html) function from `scikit-learn`.
#
# You need to call the function something like this
# ```python
# class_weights = class_weight.compute_class_weight(class_weight = , classes = , y = )
# ```
#
# otherwise it will through an error.

# %%
from sklearn.utils import class_weight

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# Calculate class weights
value1, value2 = class_weight.compute_class_weight(class_weight="balanced", classes=np.unique(Ytrain), y= Ytrain)

# Print the class weights
print(np.unique(Ytrain))

# weights are equivalent to this, easier to interpret if a weight is 1
print(value1/value2, value2/value2)

# ============================================

# Convert class weights into a dictionary that can be used as input to the model.fit() function

class_weights = {0: value1,
                1: value2}
# Out:
# [0 1]
# 5.27450175368626 1.0

# %% [markdown]
# ### Train a model using class weights. 2 hidden layers with 20 nodes each

# %%
# Setup some training and hyper-parameters
batch_size = 10000
epochs = 20

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# Specify the learning rate, the input shape and the loss function
learning_rate = 0.1
input_shape = (92,)
# Gamma is 0 then we get binarycross, higher gamma gives higher emphesis on predictions the model is not confident in. 
# (1-p)^gamma means if p is high, 0.99 it drops to 0, faster the larger gamma is.
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 0)

# Build the model
np.random.seed(123)
model2 = build_DNN(input_shape, 2, 20, loss, act_fun='sigmoid', optimizer='sgd', learning_rate=learning_rate, print_summary=True)

# Train the model, provide training data and validation data
history2 = model2.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights)
# ============================================

# %%
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------
# Evaluate model on test data
score = model2.evaluate(Xtest, Ytest, batch_size = 10000)

# ============================================
print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])

# 18040 / (18040 + 96581) = 0.1574, model panicks and only predicts the rare class after weighing.

# %%
plot_results(history2)

# %% [markdown]
# ### **Additional questions**
# #### **<span style="color:red">Questions</span>**
#
# 5. Why do we have to use a batch size? Why can't we simply use all data at once? This is more relevant for even larger datasets.
#
# 6. What is the processing time for one training epoch when the batch size is 100? What is the processing time for one epoch when the batch size is 1,000? What is the processing time for one epoch when the batch size is 10,000? Explain the results.
#
# 7. How many times are the weights in the DNN updated in each training epoch if the batch size is 100? How many times are the weights in the DNN updated in each training epoch if the batch size is 1,000? How many times are the weights in the DNN updated in each training epoch if the batch size is 10,000?
#
# 8. What limits how large the batch size can be?
#
# 9.  Generally speaking, how is the learning rate related to the batch size? If the batch size is decreased, how should the learning rate be changed?
# 10. How many trainable parameters does the network with 4 dense layers with 50 nodes each have, compared to the initial network with 2 layers and 20 nodes per layer? Hint: use model.summary()
#
# #### **<span style="color:green">Answers</span>**
# 5. We cannot fit all the data in memory. Also after a certain point E[gradient estimate] = true gradient. We are wasting compute if we compute a tiny step for the whole dataset everytime. We also want the gradient update to be slightly noisy to not get stuck in local minima. This is similar to how in metropolis-hastings we use noise to explore tje function space; if the proposal is too lighttailed we get stuck in a single peak.
#
# 6. 4/3/2 seconds. Itteration is more costly computationally because of the overhead than multiplying large matrixes, this difference becomes larger if more GPUs are present. Picking your batch_size is a balance of how big matrixes saturate the GPUs while also maintaining variance in the gradient.
#
# 7. n/10000, n/1000, n/100.
#
# 8. GPU VRAM limits us because we store the neuron outputs for each observation in the batch. (+the weights and gradients, not the issue in our case). It is possible to work around this by accumulating gradients and feeding say 10 smaller batches before updating the weights with the total gradients.
#
# 9. Smaller batchsize means more noisy update, smaller learning rate to be prefered so we don't move too far in the wrong direction.
#
# 10. (92+1)x50 + (50+1)x50x3 + 51 = 12351

# %% [markdown]
# ### **2.3 Model regularization**
#
# In the following sections you will explore methods for model normalization, namely `BatchNormalization` and `Dropout`, and also look at the impact of ofter activation functions and optimization algorithms.
# #### **2.3.1 Batch normalization**
#
# Now add batch normalization after each hidden dense layer in `build_DNN`.
#
# See the [documentation](https://keras.io/layers/normalization/) for information about how to call the function.
#
# #### **<span style="color:red">Questions</span>**
# 11. Why is batch normalization important when training deep networks?
#
# #### **<span style="color:green">Answers</span>**
# It ensures our inputs never explode which means our initialization assumptions of variance and mean hold which means our gradient will also be stable and not explode. If we have deep networks this effect is more prominent, say a gradient increase of 20%, across 10 layers this is 600%.

# %% [markdown]
# ### 2 hidden layers, 20 nodes each, class weights and batch normalization

# %%
batch_size = 10000
epochs = 20
learning_rate = 0.1
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 0)


# Build and train model
np.random.seed(123)
model6 = build_DNN(input_shape, 2, 20, loss, act_fun='sigmoid', optimizer='sgd', learning_rate=learning_rate, print_summary=True, use_bn=True)

history6 = model6.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights)

# Evaluate model on test data
score = model6.evaluate(Xtest, Ytest, batch_size = 10000)

# ============================================

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])

# Plot the history from the training run
plot_results(history6)

# %% [markdown]
# #### **2.3.2 Activation function**
#
# Try changing the activation function in each layer from sigmoid to [ReLU](https://keras.io/api/layers/activations/).
#
# **Note**: the last layer should still have a sigmoid activation function.

# %% [markdown]
# ### 2 hidden layers, 20 nodes each, class weights, ReLU and no batch normalization

# %%
batch_size = 10000
epochs = 20
learning_rate = 0.1
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 0)


# Build and train model
np.random.seed(123)
model7 = build_DNN(input_shape, 2, 20, loss, act_fun='relu', optimizer='sgd', learning_rate=learning_rate, print_summary=True, use_bn=True)

history7 = model7.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights)

# Evaluate model on test data
score = model7.evaluate(Xtest, Ytest, batch_size = 10000)

# ============================================

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])

# Plot the history from the training run
plot_results(history7)

# %% [markdown]
# #### **2.3.3 Optimizer**
#
# Try changing the optimizer from SGD to Adam (with learning rate 0.1 as before). Remember to import the Adam optimizer from [keras.optimizers](https://keras.io/optimizers/).

# %% [markdown]
# ### 2 hidden layers, 20 nodes each, class weights, Adam optimizer, no batch normalization, sigmoid activations

# %%
batch_size = 10000
epochs = 20
learning_rate = 0.1
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 0)


# Build and train model
np.random.seed(123)
model8 = build_DNN(input_shape, 2, 20, loss, act_fun='sigmoid', optimizer='adam', learning_rate=learning_rate, print_summary=True, use_bn=True)

history8 = model8.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights)

# Evaluate model on test data
score = model8.evaluate(Xtest, Ytest, batch_size = 10000)

# ============================================

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])

# Plot the history from the training run
plot_results(history8)

# %% [markdown]
# #### 2.3.4 **Dropout regularization**
#
# Dropout is a type of regularization that can improve accuracy for validation and test data. It randomly removes connections to force the neural network to not rely too much on a small number of weights.
#
# Add a Dropout layer after each Dense layer (but not after the final dense layer) in `build_DNN`, with a dropout probability of 50%. Look at the [documentation](https://keras.io/api/layers/regularization_layers/dropout/) for more information on how to call set this layer.
#
# #### **<span style="color:red">Questions</span>**
# 12. How does the validation accuracy change when adding dropout?
# 13. How does the test accuracy change when adding dropout?
#
# #### **<span style="color:green">Answers</span>**
# 12. It dropped slightly. The dropout percentage 50% is probably too high and more epochs are probably needed when running with dropout.
# 13. It dropped alot.

# %% [markdown]
# ### 2 hidden layers with 20 nodes each, class weights, dropout, SGD optimizer, no batch normalization and sigmoid activations

# %%
batch_size = 10000
# intentionally increased the epochs as dropout needs more training
epochs = 20
learning_rate = 0.1
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 0)


# Build and train model
np.random.seed(123)
model9 = build_DNN(input_shape, 2, 20, loss, act_fun='sigmoid', optimizer='sgd', learning_rate=learning_rate, print_summary=True, use_bn=False, use_dropout=0.5)

history9 = model9.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights)

# Evaluate model on test data
score = model9.evaluate(Xtest, Ytest, batch_size = 10000)

# ============================================

print('Test loss: %.4f' % score[0])
print('Test accuracy: %.4f' % score[1])

# Plot the history from the training run
plot_results(history9)

# %% [markdown]
# # Part 3:  Hyper parameter tuning
#
# ### **3.1 Manual hyper parameter tuning**
# Spend some time (20 to 30 minutes) tuning the network architecture (number of layers, number of nodes per layer, activation function) and other hyper parameters (optimizer, learning rate, batch size, number of epochs, degree of regularization). For example, try a much deeper network. How much does the training time increase for a network with 10 layers?
#
# #### **<span style="color:red">Question</span>**
# 14. How high classification accuracy can you achieve for the test data? What is your best configuration?
#
# #### **<span style="color:green">Answers</span>**
# We reached 0.9306 test accuracy. The best configuration uses class weights and focal cross entropy to focus more on harder examples and rare classes. It also uses label smoothing to ensure weights do not push the prediction further along the sigmoid function, this way the weights are optimized for what matters most instead of diminishing returns, the loss also blew up without label smoothing because of log(0). 4 layers with 40 nodes with 400 epochs seemed enough to make the model fit most of the signal in the data. We use cosine annealing as a learning rate scheduler to explore more options at the start and then gradually lower the learning rate to finetune the weights. Sigmoid activation seemed better than relu and silu, batchnorm didnt affect performance much but made training slower so was removed to increase model complexity. Slight dropout (0.1) is used to regularize.

# %%
batch_size = 20000
epochs = 400
learning_rate = 0.00001
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 1, label_smoothing=0.02)

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# Build and train model
# the gradient norm was usually between 0.2-0.6, clipping it to 2
np.random.seed(123)
best_model = build_DNN(input_shape, 4, 40, loss, act_fun='sigmoid', optimizer='adam', learning_rate=learning_rate, print_summary=True, 
                       use_bn=False, use_dropout=0.1)#, global_clipnorm=0.01)

from tf_keras.callbacks import LearningRateScheduler
import math

max_lr = 0.1
warmup_duration = round(epochs*0.2)
# cosine annealing, one cycle
#https://wiki.cloudfactory.com/docs/mp-wiki/scheduler/cosineannealinglr
def scheduler(epoch, lr):
    if epoch < warmup_duration:
        return learning_rate + epoch * (max_lr-learning_rate) / warmup_duration
    else:
        decay_duration = epochs - warmup_duration
        epochs_past_warmup = epoch - warmup_duration
        min_lr = learning_rate * 0.1 

        progress = epochs_past_warmup / decay_duration
        cosine_multiplier = 0.5 * (1 + math.cos(math.pi * progress))
        
        return min_lr + (max_lr - min_lr) * cosine_multiplier    
    
callback = LearningRateScheduler(scheduler)

best_history = best_model.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights, 
                              callbacks=[callback])
# Evaluate model on test data
best_score = best_model.evaluate(Xtest, Ytest, batch_size = batch_size)

# ============================================

print('Test loss: %.4f' % best_score[0])
print('Test accuracy: %.4f' % best_score[1])

# Plot the history from the training run
plot_results(best_history, lrbool = True)

# %% [markdown]
# #### **<span style="color:red">Questions</span>**
#
# 3. What happens if you add several Dense layers without specifying the activation function?
#
# 4. How are the weights in each dense layer initialized as default? How are the bias weights initialized?
#
# #### **<span style="color:green">Answers</span>**
# 3. The activation function is sigmoid by default in this network. If it is unspecified we get sigmoid.
# 4. Weights are initialized via glorot initialization according to Keras' documenation. Biases are initizalized to 0.

# %% [markdown]
# ### **3.2 Automatic hyper parameter search**
# The number of hyper parameters that can be tried manually is limited and the process of trying out the different combinations and keeping track of them is time consuming and tedious. Today, there are several libraries available for automatic hyper parameter tuning (see an extensive list [here](https://github.com/balavenkatesh3322/hyperparameter_tuning)). The library that we will use in this lab is `Ray Tune` which can be integrated with many of the deep learning APIs available today (for the full description of the library capabilities see the [documentation](https://docs.ray.io/en/latest/tune/index.html)).
#
#
# To use the `Ray Tune` functionality we need a function that defines the model training. This will then be used in a wrapper function that defines the hyper parameter search space, the resources available for running the search and the search algorithm.
#
# Start by implementing the `train_DNN` function in the `utilities.py` file (more detailed instructions are available in `utilities.py`). In the cell below, you can set up the search space and a `tune` ray object that takes the `train_DNN`. The tuner will set `train_DNN`, will select a set of hyper parameters and train several models for us (more information [here](https://docs.ray.io/en/latest/tune/key-concepts.html?_gl=1*j3ryje*_up*MQ..*_ga*NzQyMjIzNzg4LjE3MzY0MTk5MzY.*_ga_0LCWHW1N3S*MTczNjQxOTkzNS4xLjAuMTczNjQxOTkzNS4wLjAuMA..#tune-60-seconds)).
#
#
# `Ray Tune` library provides several types of hyper parameter search algorithms, including random and grid search, and Bayesian optimization. In this lab we will be using the default Ray Tune opitmization algorithm which is random serach. More infromation about the available search arlgorithms can be found [here](https://docs.ray.io/en/latest/tune/api/suggestion.html).
#
# #### **<span style="color:red">Question</span>**
# 15. Run the automatic hyper parameter search with range of possible hyper parameter values as in your manual search. Does the automatic search set of parameters match those that you have found?
# 16. What are the benefits and drawbacks of automatic hyper parameter search?
#
# #### **<span style="color:green">Answers</span>**
# It is not 1 to 1 as the hyperparameter search is on 25 epochs. It would not be feasible to run 400 epoch hyperparam search on this computer. The hope is that accuracy at 25 epochs indicates accuracy at 400. The learning rate scheduler behaves differently on lower epochs, dropout aswell. Maybe less complex models are favored, running the best configuration with the same amount of epochs as the best one. The hyperparameters were actually pretty similar to the manual ones which is interesting. The biggest difference is the amount of layers (1 with 25 neurons VS manual which had 4 and 40). The manual hyper parameter search got 0.93 vs 0.926 accuracy from the automatic hyperparam search. Manual hyperparameter search requires human input, it can be good to get a feel for the range of hyperparameters in the automatic hyperparameter search. In manual one, insight can be gained from the loss curves which automatic hyperparameter search as structured here doesn't account for. Say one modeltraining takes hours, then humanled hyperparameters are probably superior, if the modeltraining takes 5 seconds, automatic tuning is better.

# %%
# import train_DNN
from utilities import train_DNN

# imports for hyperparameter tuning
from ray import tune, train
from ray.tune.schedulers import AsyncHyperBandScheduler

import os

# windows fix:

os.environ["RAY_TMPDIR"] = "C:/ray_tmp" 

def custom_dirname_creator(trial):
    return f"trial_{trial.trial_id}"

# --------------------------------------------  
# === Your code here =========================
# --------------------------------------------

# Define the hyper parameter, both those that should be searched and those that are fixed.
#  Hyperparameters to search are: act_fun, optimizer, use_bn, n_hidden_layers and n_hidden_units.
# The remaining parameters can be set to fixed values (This is to reduce the search space and time).
# Add the batch size and epochs so that the train_DNN can access them.


hyperparameter_space =  {
            "act_fun": tune.choice(["sigmoid", "silu", "relu"]),
            "optimizer": tune.choice(["adam"]),
            "use_bn": tune.choice([True, False]),
            "n_hidden_layers": tune.randint(1, 5),
            "n_hidden_units": tune.randint(5, 50),
            # here define the fixed parameters
            #"loss": ???, 
            "learning_rate": 0.00001,
            "use_dropout": tune.uniform(0, 0.4),
            "use_custom_dropout": False,
            #"use_variational_layer": ???,
            "input_shape": (92, ),
            "max_lr": tune.loguniform(1e-2, 1e1),
            "gamma": tune.uniform(0, 2)
        }

# specify batch and number of epochs
training_config = {
            "data": (Xtrain, Ytrain, Xval, Yval),
            "epochs": 25,
            "batch_size": 20000
        }

# specify the number of samples to take from the hyper parameter space and run. The larger the number, the longer the search time.
# Start small (e.g. 2) to test your implementation, then increase.
num_samples = 50

# ============================================


# Definition of the Scheduler. This allows for several models to be trained/stopped/re-started simultaneously 
sched = AsyncHyperBandScheduler(
    metric="mean_accuracy", mode="max",
        time_attr="training_iteration", max_t=400, grace_period=20
    )

# Setting up the tuner.
tuner = tune.Tuner(
        tune.with_resources(tune.with_parameters(train_DNN, training_config=training_config), resources={"cpu": 8, "gpu":0}), # definition of which training function to use and the available resources. Consider adding "gpu":0 to resources if available.
        tune_config=tune.TuneConfig(
            scheduler=sched,
            num_samples=num_samples,
            trial_dirname_creator=custom_dirname_creator
        ),
        run_config=tune.RunConfig(
            name="DNN_hp_tuning",
            stop={"mean_accuracy": 1},
            storage_path='C:/Users/arone/Desktop/Ray_results' # where to save the summary of the hyper parameter tuning.
        ),
        param_space=hyperparameter_space,
    )

# Run the hyper parameter search.
results = tuner.fit()

# %%
# Show the best hyper parameter configuration that was found
best_trial = results.get_best_result(metric="mean_accuracy", mode='max')
print(f"Best trial config: {best_trial.config}")
print(f"Best trial final validation loss: {best_trial.metrics['keras_info']['val_loss']:0.4f}")
print(f"Best trial final validation accuracy: {best_trial.metrics['keras_info']['val_accuracy']:0.4f}")

# %% [markdown]
# Best trial config: {'act_fun': 'sigmoid', 'optimizer': 'adam', 'use_bn': False, 'n_hidden_layers': 1, 'n_hidden_units': 25, 'learning_rate': 1e-05, 'use_dropout': 0.002377137489411929, 'use_custom_dropout': False, 'input_shape': (92,), 'max_lr': 0.12507121758522902, 'gamma': 1.0677719633965892}

# %%
batch_size = 20000
epochs = 25
learning_rate = 0.00001
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 1.0677719633965892, label_smoothing=0.02)

# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# Build and train model
# the gradient norm was usually between 0.2-0.6, clipping it to 2
np.random.seed(123)
best_model = build_DNN(input_shape, 1, 25, loss, act_fun='sigmoid', optimizer='adam', learning_rate=learning_rate, print_summary=True, 
                       use_bn=False, use_dropout=0.002377137489411929)#, global_clipnorm=0.01)

from tf_keras.callbacks import LearningRateScheduler
import math

max_lr = 0.12507121758522902
warmup_duration = round(epochs*0.2)
# cosine annealing, one cycle
#https://wiki.cloudfactory.com/docs/mp-wiki/scheduler/cosineannealinglr
def scheduler(epoch, lr):
    if epoch < warmup_duration:
        return learning_rate + epoch * (max_lr-learning_rate) / warmup_duration
    else:
        decay_duration = epochs - warmup_duration
        epochs_past_warmup = epoch - warmup_duration
        min_lr = learning_rate * 0.1 

        progress = epochs_past_warmup / decay_duration
        cosine_multiplier = 0.5 * (1 + math.cos(math.pi * progress))
        
        return min_lr + (max_lr - min_lr) * cosine_multiplier    
    
callback = LearningRateScheduler(scheduler)

best_history = best_model.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights, 
                              callbacks=[callback])
# Evaluate model on test data
best_score = best_model.evaluate(Xtest, Ytest, batch_size = batch_size)

# ============================================

print('Test loss: %.4f' % best_score[0])
print('Test accuracy: %.4f' % best_score[1])

# Plot the history from the training run
plot_results(best_history)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 25)                2325
#
#  dropout (Dropout)           (None, 25)                0
#
#  dense_4 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 2351 (9.18 KB)
# Trainable params: 2351 (9.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# WARNING:tensorflow:From c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 27/27 [==============================] - 7s 63ms/step - loss: 0.1013 - accuracy: 0.8837 - val_loss: 0.0820 - val_accuracy: 0.9111 - lr: 0.1251
# Epoch 2/2
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0811 - accuracy: 0.9099 - val_loss: 0.0788 - val_accuracy: 0.9133 - lr: 0.0625
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0788 - accuracy: 0.9121
# Test loss: 0.0788
# Test accuracy: 0.9121

# %% [markdown]
# # Part 4: Uncertainty quantification
#
# In the next sections you will explore three methods for model uncertainty estimation:
# - Monte Carlo dropout where we take advantage of the dropout layer during inference time.
# - Cross validation where we train several models on different splits of data.
# - Bayesian neural networks (BNN) where we modify our model definition to allow the model to learn distributions over weights and the output.
#
# **!Note**: through the next sections, use your best model configuration that you found through hyper parameter tuning (either manual or automatic).

# %% [markdown]
# ### **4.1 Dropout uncertainty**
#
# Dropout can also be used during testing, to obtain an estimate of the model uncertainty. Since dropout will randomly remove connections, the network will produce different results every time the same (test) data is put into the network. This technique is called Monte Carlo dropout. For more information, see this [paper](http://proceedings.mlr.press/v48/gal16.pdf)
#
# To achieve this, we need to redefine the Keras Dropout. This was already done for you and it is available in `utilities.py` under `myDropout`. Adapt the `build_DNN` function to two boolean arguments, use_dropout and use_custom_dropout; add a standard Dropout layer if use_dropout is true, add a `myDropout` layer if use_custom_dropout is true.
#
# Run the same test data through the trained network 100 times, with dropout turned on.

# %%
max_lr = 0.1
warmup_duration = round(epochs*0.2)
# cosine annealing, one cycle
#https://wiki.cloudfactory.com/docs/mp-wiki/scheduler/cosineannealinglr
def scheduler(epoch, lr):
    if epoch < warmup_duration:
        return learning_rate + epoch * (max_lr-learning_rate) / warmup_duration
    else:
        decay_duration = epochs - warmup_duration
        epochs_past_warmup = epoch - warmup_duration
        min_lr = learning_rate * 0.1 

        progress = epochs_past_warmup / decay_duration
        cosine_multiplier = 0.5 * (1 + math.cos(math.pi * progress))
        
        return min_lr + (max_lr - min_lr) * cosine_multiplier    
    
callback = LearningRateScheduler(scheduler)


best_score = best_model.evaluate(Xtest, Ytest, batch_size = batch_size)

# ============================================




# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# epochs = 20 gives this test accuracy instead 0.9214

# Your best training parameters
batch_size = 20000
epochs = 25
learning_rate = 0.00001
input_shape = (92,)
loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 1, label_smoothing=0.02)

# Build and train model
np.random.seed(123)
model10 = build_DNN(input_shape, 4, 40, loss, act_fun='sigmoid', optimizer='adam', learning_rate=learning_rate, print_summary=True, 
                       use_bn=False, use_custom_dropout=0.1)

history10 =  model10.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights, 
                              callbacks=[callback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 19
#      15         cosine_multiplier = 0.5 * (1 + math.cos(math.pi * progress))
#      17         return min_lr + (max_lr - min_lr) * cosine_multiplier
# ---> 19 callback = LearningRateScheduler(scheduler)
#      22 best_score = best_model.evaluate(Xtest, Ytest, batch_size = batch_size)
#      24 # ============================================
#      25
#      26
#    (...)     34
#      35 # Your best training parameters
#
# NameError: name 'LearningRateScheduler' is not defined

# %%
# Run this cell a few times to evalute the model on test data, 
# if you get slightly different test accuracy every time, Dropout during testing is working

# Evaluate model on test data
score = model10.evaluate(Xtest, Ytest, verbose=0)
                       
print('Test accuracy: %.4f' % score[1])

# %%
# ============================================
# === Your code here =========================
# ============================================
# Run the testing 100 times, and save the accuracies in an array
score = np.array([model10.evaluate(Xtest, Ytest, verbose=0) for i in range(100)])



# ============================================

# %%
# Calculate and print mean and std of accuracies
print(score.mean(axis = 0))
print(score.std(axis = 0))
# left is loss, right is accuracy.
score

# %% [markdown]
# ### **4.2: Cross validation uncertainty**
#
# Cross validation (CV) is often used to evaluate a model, by training and testing using different subsets of the data it is possible to get the uncertainty as the standard deviation over folds. We here use a [help function from scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html) to setup the CV. Use 10 folds with shuffling, random state 1234.
#
# Note: We here assume that you have found the best hyper parameters, so here the data are only split into training and testing, no validation.

# %%
from sklearn.model_selection import StratifiedKFold

random_state = 1234 
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# Define 10-fold cross validation
n_splits = 10
skf = StratifiedKFold(n_splits = n_splits, random_state = random_state, shuffle = True)
X_combined = np.vstack((Xtrain, Xval))
Y_combined = np.concatenate((Ytrain, Yval))

# Define where to save the test accuracies
test_accuracies = np.zeros(n_splits, dtype=float)

i = 0
# Loop over cross validation folds
for train_index, test_index in skf.split(X_combined, Y_combined):

    x_train = X_combined[train_index, :]
    y_train = Y_combined[train_index]

    x_val, y_val = X_combined[test_index, :], Y_combined[test_index]

    # Calculate class weights for current split (remember to call the function using the input variable names e.g. class_weight='balanced', etc.)
    value1, value2 = class_weight.compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y= y_train)

    class_weights = {0: value1,
                    1: value2}
    


    batch_size = 20000
    epochs = 25
    learning_rate = 0.00001
    input_shape = (92,)
    loss = tf.keras.losses.BinaryFocalCrossentropy(gamma = 1, label_smoothing=0.02)

    np.random.seed(123)
    model = build_DNN(input_shape, 4, 40, loss, act_fun='sigmoid', optimizer='adam', learning_rate=learning_rate, print_summary=True, 
                        use_bn=False, use_custom_dropout=0.1)



    history =  model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size, class_weight = class_weights, 
                                callbacks=[callback])
    
    # Evaluate the model using the test set for this fold
    score = model.evaluate(x_val, y_val, verbose=0)

    # Save the test accuracy in an array
    test_accuracies[i] = score[1]
    i = i + 1

# Calculate and print mean and std of accuracies
print(test_accuracies.mean())
print(test_accuracies.std())

# ============================================
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 40)                3720
#
#  my_dropout (myDropout)      (None, 40)                0
#
#  dense_6 (Dense)             (None, 40)                1640
#
#  my_dropout_1 (myDropout)    (None, 40)                0
#
#  dense_7 (Dense)             (None, 40)                1640
#
#  my_dropout_2 (myDropout)    (None, 40)                0
#
#  dense_8 (Dense)             (None, 40)                1640
#
#  my_dropout_3 (myDropout)    (None, 40)                0
#
#  dense_9 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 5s 74ms/step - loss: 0.3198 - accuracy: 0.8096 - val_loss: 0.2277 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2277 - accuracy: 0.8405 - val_loss: 0.2263 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2260 - accuracy: 0.8405 - val_loss: 0.2257 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.2256 - accuracy: 0.8405 - val_loss: 0.2255 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2254 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 2s 65ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 2s 76ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 2s 68ms/step - loss: 0.2249 - accuracy: 0.8405 - val_loss: 0.2237 - val_accuracy: 0.8405 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1767 - accuracy: 0.8523 - val_loss: 0.1343 - val_accuracy: 0.8814 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1295 - accuracy: 0.8859 - val_loss: 0.1285 - val_accuracy: 0.8884 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1269 - accuracy: 0.8899 - val_loss: 0.1243 - val_accuracy: 0.8941 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.1255 - accuracy: 0.8917 - val_loss: 0.1252 - val_accuracy: 0.8896 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 2s 56ms/step - loss: 0.1242 - accuracy: 0.8925 - val_loss: 0.1240 - val_accuracy: 0.8923 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.1233 - accuracy: 0.8928 - val_loss: 0.1228 - val_accuracy: 0.8946 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.1225 - accuracy: 0.8940 - val_loss: 0.1222 - val_accuracy: 0.8953 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.1227 - accuracy: 0.8944 - val_loss: 0.1218 - val_accuracy: 0.8949 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1218 - accuracy: 0.8953 - val_loss: 0.1215 - val_accuracy: 0.8960 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1215 - accuracy: 0.8954 - val_loss: 0.1207 - val_accuracy: 0.8959 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.1221 - accuracy: 0.8953 - val_loss: 0.1223 - val_accuracy: 0.8952 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1222 - accuracy: 0.8952 - val_loss: 0.1222 - val_accuracy: 0.8945 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.1222 - accuracy: 0.8952 - val_loss: 0.1229 - val_accuracy: 0.8944 - lr: 4.9411e-04
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 40)                3720
#
#  my_dropout_4 (myDropout)    (None, 40)                0
#
#  dense_11 (Dense)            (None, 40)                1640
#
#  my_dropout_5 (myDropout)    (None, 40)                0
#
#  dense_12 (Dense)            (None, 40)                1640
#
#  my_dropout_6 (myDropout)    (None, 40)                0
#
#  dense_13 (Dense)            (None, 40)                1640
#
#  my_dropout_7 (myDropout)    (None, 40)                0
#
#  dense_14 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 3s 54ms/step - loss: 0.3487 - accuracy: 0.7782 - val_loss: 0.2301 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2278 - accuracy: 0.8405 - val_loss: 0.2265 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.2258 - accuracy: 0.8405 - val_loss: 0.2255 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2258 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2254 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2233 - accuracy: 0.8405 - val_loss: 0.2054 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1615 - accuracy: 0.8405 - val_loss: 0.1417 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1353 - accuracy: 0.8405 - val_loss: 0.1294 - val_accuracy: 0.8407 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1255 - accuracy: 0.8405 - val_loss: 0.1224 - val_accuracy: 0.8422 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.1102 - accuracy: 0.8731 - val_loss: 0.1027 - val_accuracy: 0.8811 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1002 - accuracy: 0.8860 - val_loss: 0.0987 - val_accuracy: 0.8881 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0980 - accuracy: 0.8908 - val_loss: 0.0978 - val_accuracy: 0.8890 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0963 - accuracy: 0.8918 - val_loss: 0.0973 - val_accuracy: 0.8885 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0955 - accuracy: 0.8927 - val_loss: 0.0951 - val_accuracy: 0.8934 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0941 - accuracy: 0.8920 - val_loss: 0.0936 - val_accuracy: 0.8920 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0928 - accuracy: 0.8926 - val_loss: 0.0923 - val_accuracy: 0.8926 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0920 - accuracy: 0.8935 - val_loss: 0.0927 - val_accuracy: 0.8924 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0917 - accuracy: 0.8938 - val_loss: 0.0917 - val_accuracy: 0.8933 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0916 - accuracy: 0.8938 - val_loss: 0.0913 - val_accuracy: 0.8954 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0914 - accuracy: 0.8937 - val_loss: 0.0925 - val_accuracy: 0.8926 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0913 - accuracy: 0.8946 - val_loss: 0.0918 - val_accuracy: 0.8931 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0911 - accuracy: 0.8946 - val_loss: 0.0911 - val_accuracy: 0.8939 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0909 - accuracy: 0.8950 - val_loss: 0.0918 - val_accuracy: 0.8935 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0908 - accuracy: 0.8950 - val_loss: 0.0912 - val_accuracy: 0.8944 - lr: 4.9411e-04
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 40)                3720
#
#  my_dropout_8 (myDropout)    (None, 40)                0
#
#  dense_16 (Dense)            (None, 40)                1640
#
#  my_dropout_9 (myDropout)    (None, 40)                0
#
#  dense_17 (Dense)            (None, 40)                1640
#
#  my_dropout_10 (myDropout)   (None, 40)                0
#
#  dense_18 (Dense)            (None, 40)                1640
#
#  my_dropout_11 (myDropout)   (None, 40)                0
#
#  dense_19 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 3s 51ms/step - loss: 0.3349 - accuracy: 0.8012 - val_loss: 0.2278 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2260 - accuracy: 0.8405 - val_loss: 0.2128 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1619 - accuracy: 0.8559 - val_loss: 0.1301 - val_accuracy: 0.8965 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1257 - accuracy: 0.8961 - val_loss: 0.1264 - val_accuracy: 0.8982 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1242 - accuracy: 0.8973 - val_loss: 0.1111 - val_accuracy: 0.8965 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0975 - accuracy: 0.8996 - val_loss: 0.0932 - val_accuracy: 0.9044 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0932 - accuracy: 0.9044 - val_loss: 0.0929 - val_accuracy: 0.9051 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0939 - accuracy: 0.9034 - val_loss: 0.0945 - val_accuracy: 0.9034 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0931 - accuracy: 0.9042 - val_loss: 0.0927 - val_accuracy: 0.9047 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0923 - accuracy: 0.9052 - val_loss: 0.0929 - val_accuracy: 0.9049 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0930 - accuracy: 0.9060 - val_loss: 0.0950 - val_accuracy: 0.9004 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0933 - accuracy: 0.9045 - val_loss: 0.0942 - val_accuracy: 0.9048 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0916 - accuracy: 0.9085 - val_loss: 0.0914 - val_accuracy: 0.9073 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0905 - accuracy: 0.9107 - val_loss: 0.0915 - val_accuracy: 0.9087 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0905 - accuracy: 0.9090 - val_loss: 0.0915 - val_accuracy: 0.9085 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0895 - accuracy: 0.9117 - val_loss: 0.0896 - val_accuracy: 0.9109 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0894 - accuracy: 0.9120 - val_loss: 0.0883 - val_accuracy: 0.9131 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0877 - accuracy: 0.9140 - val_loss: 0.0880 - val_accuracy: 0.9139 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0878 - accuracy: 0.9140 - val_loss: 0.0899 - val_accuracy: 0.9132 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0877 - accuracy: 0.9141 - val_loss: 0.0874 - val_accuracy: 0.9141 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0873 - accuracy: 0.9145 - val_loss: 0.0877 - val_accuracy: 0.9143 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0872 - accuracy: 0.9146 - val_loss: 0.0876 - val_accuracy: 0.9143 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0874 - accuracy: 0.9145 - val_loss: 0.0871 - val_accuracy: 0.9142 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0873 - accuracy: 0.9146 - val_loss: 0.0875 - val_accuracy: 0.9144 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0878 - accuracy: 0.9144 - val_loss: 0.0869 - val_accuracy: 0.9144 - lr: 4.9411e-04
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 40)                3720
#
#  my_dropout_12 (myDropout)   (None, 40)                0
#
#  dense_21 (Dense)            (None, 40)                1640
#
#  my_dropout_13 (myDropout)   (None, 40)                0
#
#  dense_22 (Dense)            (None, 40)                1640
#
#  my_dropout_14 (myDropout)   (None, 40)                0
#
#  dense_23 (Dense)            (None, 40)                1640
#
#  my_dropout_15 (myDropout)   (None, 40)                0
#
#  dense_24 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 3s 55ms/step - loss: 0.2217 - accuracy: 0.8377 - val_loss: 0.0957 - val_accuracy: 0.8818 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0885 - accuracy: 0.8950 - val_loss: 0.0863 - val_accuracy: 0.9077 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0830 - accuracy: 0.9121 - val_loss: 0.0829 - val_accuracy: 0.9110 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0825 - accuracy: 0.9124 - val_loss: 0.0823 - val_accuracy: 0.9126 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0810 - accuracy: 0.9149 - val_loss: 0.0820 - val_accuracy: 0.9131 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0807 - accuracy: 0.9153 - val_loss: 0.0814 - val_accuracy: 0.9149 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0799 - accuracy: 0.9169 - val_loss: 0.0805 - val_accuracy: 0.9150 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0790 - accuracy: 0.9180 - val_loss: 0.0796 - val_accuracy: 0.9167 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0792 - accuracy: 0.9176 - val_loss: 0.0798 - val_accuracy: 0.9164 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0782 - accuracy: 0.9189 - val_loss: 0.0792 - val_accuracy: 0.9170 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0779 - accuracy: 0.9189 - val_loss: 0.0793 - val_accuracy: 0.9168 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0773 - accuracy: 0.9184 - val_loss: 0.0768 - val_accuracy: 0.9149 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0749 - accuracy: 0.9181 - val_loss: 0.0756 - val_accuracy: 0.9158 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0733 - accuracy: 0.9185 - val_loss: 0.0737 - val_accuracy: 0.9162 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0724 - accuracy: 0.9188 - val_loss: 0.0729 - val_accuracy: 0.9154 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0711 - accuracy: 0.9185 - val_loss: 0.0711 - val_accuracy: 0.9175 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0700 - accuracy: 0.9189 - val_loss: 0.0720 - val_accuracy: 0.9158 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0696 - accuracy: 0.9189 - val_loss: 0.0700 - val_accuracy: 0.9180 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0689 - accuracy: 0.9194 - val_loss: 0.0698 - val_accuracy: 0.9170 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0686 - accuracy: 0.9191 - val_loss: 0.0698 - val_accuracy: 0.9178 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0683 - accuracy: 0.9193 - val_loss: 0.0693 - val_accuracy: 0.9175 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0680 - accuracy: 0.9195 - val_loss: 0.0686 - val_accuracy: 0.9180 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 3s 100ms/step - loss: 0.0678 - accuracy: 0.9196 - val_loss: 0.0687 - val_accuracy: 0.9175 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 4s 121ms/step - loss: 0.0677 - accuracy: 0.9197 - val_loss: 0.0688 - val_accuracy: 0.9167 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0677 - accuracy: 0.9196 - val_loss: 0.0686 - val_accuracy: 0.9180 - lr: 4.9411e-04
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 40)                3720
#
#  my_dropout_16 (myDropout)   (None, 40)                0
#
#  dense_26 (Dense)            (None, 40)                1640
#
#  my_dropout_17 (myDropout)   (None, 40)                0
#
#  dense_27 (Dense)            (None, 40)                1640
#
#  my_dropout_18 (myDropout)   (None, 40)                0
#
#  dense_28 (Dense)            (None, 40)                1640
#
#  my_dropout_19 (myDropout)   (None, 40)                0
#
#  dense_29 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 9s 55ms/step - loss: 0.3633 - accuracy: 0.7754 - val_loss: 0.2266 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 2s 60ms/step - loss: 0.2278 - accuracy: 0.8405 - val_loss: 0.2266 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 2s 54ms/step - loss: 0.2260 - accuracy: 0.8405 - val_loss: 0.2257 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 2s 66ms/step - loss: 0.2256 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2234 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.1951 - accuracy: 0.8405 - val_loss: 0.1496 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 2s 64ms/step - loss: 0.1431 - accuracy: 0.8405 - val_loss: 0.1397 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.1387 - accuracy: 0.8405 - val_loss: 0.1372 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.1377 - accuracy: 0.8405 - val_loss: 0.1368 - val_accuracy: 0.8405 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1375 - accuracy: 0.8405 - val_loss: 0.1366 - val_accuracy: 0.8405 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 1s 48ms/step - loss: 0.1369 - accuracy: 0.8405 - val_loss: 0.1359 - val_accuracy: 0.8405 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.1364 - accuracy: 0.8405 - val_loss: 0.1365 - val_accuracy: 0.8405 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 2s 56ms/step - loss: 0.1369 - accuracy: 0.8405 - val_loss: 0.1373 - val_accuracy: 0.8405 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.1366 - accuracy: 0.8405 - val_loss: 0.1362 - val_accuracy: 0.8405 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1362 - accuracy: 0.8405 - val_loss: 0.1361 - val_accuracy: 0.8405 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1358 - accuracy: 0.8405 - val_loss: 0.1357 - val_accuracy: 0.8405 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1357 - accuracy: 0.8405 - val_loss: 0.1358 - val_accuracy: 0.8405 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 48ms/step - loss: 0.1357 - accuracy: 0.8405 - val_loss: 0.1353 - val_accuracy: 0.8405 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1357 - accuracy: 0.8405 - val_loss: 0.1346 - val_accuracy: 0.8405 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1355 - accuracy: 0.8405 - val_loss: 0.1351 - val_accuracy: 0.8405 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.1355 - accuracy: 0.8405 - val_loss: 0.1357 - val_accuracy: 0.8405 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1354 - accuracy: 0.8405 - val_loss: 0.1355 - val_accuracy: 0.8405 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1353 - accuracy: 0.8405 - val_loss: 0.1358 - val_accuracy: 0.8405 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1353 - accuracy: 0.8405 - val_loss: 0.1353 - val_accuracy: 0.8405 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.1351 - accuracy: 0.8405 - val_loss: 0.1351 - val_accuracy: 0.8405 - lr: 4.9411e-04
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 40)                3720
#
#  my_dropout_20 (myDropout)   (None, 40)                0
#
#  dense_31 (Dense)            (None, 40)                1640
#
#  my_dropout_21 (myDropout)   (None, 40)                0
#
#  dense_32 (Dense)            (None, 40)                1640
#
#  my_dropout_22 (myDropout)   (None, 40)                0
#
#  dense_33 (Dense)            (None, 40)                1640
#
#  my_dropout_23 (myDropout)   (None, 40)                0
#
#  dense_34 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 3s 55ms/step - loss: 0.3301 - accuracy: 0.7927 - val_loss: 0.2313 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2273 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.1868 - accuracy: 0.8405 - val_loss: 0.1163 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0982 - accuracy: 0.8802 - val_loss: 0.0938 - val_accuracy: 0.8881 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0942 - accuracy: 0.8887 - val_loss: 0.0928 - val_accuracy: 0.8919 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0917 - accuracy: 0.8933 - val_loss: 0.0921 - val_accuracy: 0.8912 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0909 - accuracy: 0.8948 - val_loss: 0.0895 - val_accuracy: 0.8988 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0892 - accuracy: 0.8983 - val_loss: 0.0884 - val_accuracy: 0.9023 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0885 - accuracy: 0.9000 - val_loss: 0.0886 - val_accuracy: 0.8996 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0869 - accuracy: 0.9024 - val_loss: 0.0855 - val_accuracy: 0.9053 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0850 - accuracy: 0.9081 - val_loss: 0.0846 - val_accuracy: 0.9090 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0838 - accuracy: 0.9096 - val_loss: 0.0837 - val_accuracy: 0.9097 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0828 - accuracy: 0.9111 - val_loss: 0.0826 - val_accuracy: 0.9114 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0824 - accuracy: 0.9117 - val_loss: 0.0820 - val_accuracy: 0.9134 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0816 - accuracy: 0.9130 - val_loss: 0.0816 - val_accuracy: 0.9127 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0814 - accuracy: 0.9134 - val_loss: 0.0822 - val_accuracy: 0.9119 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0816 - accuracy: 0.9133 - val_loss: 0.0812 - val_accuracy: 0.9137 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0810 - accuracy: 0.9141 - val_loss: 0.0813 - val_accuracy: 0.9139 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0809 - accuracy: 0.9144 - val_loss: 0.0808 - val_accuracy: 0.9143 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0805 - accuracy: 0.9148 - val_loss: 0.0806 - val_accuracy: 0.9149 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0805 - accuracy: 0.9148 - val_loss: 0.0805 - val_accuracy: 0.9150 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0804 - accuracy: 0.9150 - val_loss: 0.0805 - val_accuracy: 0.9151 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0803 - accuracy: 0.9150 - val_loss: 0.0805 - val_accuracy: 0.9149 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0803 - accuracy: 0.9151 - val_loss: 0.0804 - val_accuracy: 0.9151 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0803 - accuracy: 0.9150 - val_loss: 0.0807 - val_accuracy: 0.9147 - lr: 4.9411e-04
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 40)                3720
#
#  my_dropout_24 (myDropout)   (None, 40)                0
#
#  dense_36 (Dense)            (None, 40)                1640
#
#  my_dropout_25 (myDropout)   (None, 40)                0
#
#  dense_37 (Dense)            (None, 40)                1640
#
#  my_dropout_26 (myDropout)   (None, 40)                0
#
#  dense_38 (Dense)            (None, 40)                1640
#
#  my_dropout_27 (myDropout)   (None, 40)                0
#
#  dense_39 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 3s 62ms/step - loss: 0.3396 - accuracy: 0.7841 - val_loss: 0.2401 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2284 - accuracy: 0.8405 - val_loss: 0.2260 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2257 - accuracy: 0.8405 - val_loss: 0.2257 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 2s 53ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2255 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 1s 48ms/step - loss: 0.2254 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 2s 61ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 2s 54ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 2s 69ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 2s 54ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 2s 55ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 2s 69ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 48ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 2s 58ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 4.9411e-04
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 40)                3720
#
#  my_dropout_28 (myDropout)   (None, 40)                0
#
#  dense_41 (Dense)            (None, 40)                1640
#
#  my_dropout_29 (myDropout)   (None, 40)                0
#
#  dense_42 (Dense)            (None, 40)                1640
#
#  my_dropout_30 (myDropout)   (None, 40)                0
#
#  dense_43 (Dense)            (None, 40)                1640
#
#  my_dropout_31 (myDropout)   (None, 40)                0
#
#  dense_44 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 5s 71ms/step - loss: 0.3953 - accuracy: 0.7574 - val_loss: 0.2539 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2319 - accuracy: 0.8405 - val_loss: 0.2258 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 2s 57ms/step - loss: 0.2261 - accuracy: 0.8405 - val_loss: 0.2255 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 2s 53ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2255 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 2s 69ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 2s 55ms/step - loss: 0.2254 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 2s 59ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 2s 53ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 2s 55ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 2s 56ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 2s 65ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 2s 67ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 2s 73ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 2s 61ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 2s 61ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 2s 63ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 48ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 2s 67ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 2s 58ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 2s 62ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 4.9411e-04
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 40)                3720
#
#  my_dropout_32 (myDropout)   (None, 40)                0
#
#  dense_46 (Dense)            (None, 40)                1640
#
#  my_dropout_33 (myDropout)   (None, 40)                0
#
#  dense_47 (Dense)            (None, 40)                1640
#
#  my_dropout_34 (myDropout)   (None, 40)                0
#
#  dense_48 (Dense)            (None, 40)                1640
#
#  my_dropout_35 (myDropout)   (None, 40)                0
#
#  dense_49 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 4s 76ms/step - loss: 0.4530 - accuracy: 0.7937 - val_loss: 0.2339 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2277 - accuracy: 0.8405 - val_loss: 0.2263 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.2258 - accuracy: 0.8405 - val_loss: 0.2256 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2254 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2253 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 50ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 4.9411e-04
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 40)                3720
#
#  my_dropout_36 (myDropout)   (None, 40)                0
#
#  dense_51 (Dense)            (None, 40)                1640
#
#  my_dropout_37 (myDropout)   (None, 40)                0
#
#  dense_52 (Dense)            (None, 40)                1640
#
#  my_dropout_38 (myDropout)   (None, 40)                0
#
#  dense_53 (Dense)            (None, 40)                1640
#
#  my_dropout_39 (myDropout)   (None, 40)                0
#
#  dense_54 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 8681 (33.91 KB)
# Trainable params: 8681 (33.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 30/30 [==============================] - 3s 51ms/step - loss: 0.3689 - accuracy: 0.7759 - val_loss: 0.2287 - val_accuracy: 0.8405 - lr: 0.1251
# Epoch 2/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2289 - accuracy: 0.8405 - val_loss: 0.2260 - val_accuracy: 0.8405 - lr: 0.1246
# Epoch 3/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2261 - accuracy: 0.8405 - val_loss: 0.2258 - val_accuracy: 0.8405 - lr: 0.1231
# Epoch 4/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2257 - accuracy: 0.8405 - val_loss: 0.2257 - val_accuracy: 0.8405 - lr: 0.1207
# Epoch 5/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2255 - accuracy: 0.8405 - val_loss: 0.2254 - val_accuracy: 0.8405 - lr: 0.1173
# Epoch 6/25
# 30/30 [==============================] - 1s 43ms/step - loss: 0.2254 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.1131
# Epoch 7/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2253 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.1081
# Epoch 8/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2252 - accuracy: 0.8405 - val_loss: 0.2252 - val_accuracy: 0.8405 - lr: 0.1024
# Epoch 9/25
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0960
# Epoch 10/25
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0892
# Epoch 11/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2251 - val_accuracy: 0.8405 - lr: 0.0819
# Epoch 12/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2251 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0743
# Epoch 13/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0665
# Epoch 14/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0586
# Epoch 15/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0508
# Epoch 16/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0432
# Epoch 17/25
# 30/30 [==============================] - 1s 42ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0359
# Epoch 18/25
# 30/30 [==============================] - 1s 44ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0290
# Epoch 19/25
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0227
# Epoch 20/25
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0169
# Epoch 21/25
# 30/30 [==============================] - 2s 65ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0119
# Epoch 22/25
# 30/30 [==============================] - 2s 76ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0077
# Epoch 23/25
# 30/30 [==============================] - 2s 60ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0044
# Epoch 24/25
# 30/30 [==============================] - 2s 59ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 0.0020
# Epoch 25/25
# 30/30 [==============================] - 2s 57ms/step - loss: 0.2250 - accuracy: 0.8405 - val_loss: 0.2250 - val_accuracy: 0.8405 - lr: 4.9411e-04
# 0.8736780345439911
# 0.03399732797258583

# %% [markdown]
# ### **4.3 Bayesian neural networks (BNN)**
#
# Instead of mimicking Bayesian inference through MC dropout (see more details in this [paper](https://proceedings.mlr.press/v48/gal16.html)), what if we could build a model that can inherently give us a way to probe both model uncertainty (i.e. [epistemic uncertainty](https://link.springer.com/article/10.1007/s10994-021-05946-3) cause by few training samples) and data uncertainty (i.e. [aleatoric uncertainty](https://link.springer.com/article/10.1007/s10994-021-05946-3))?
#
# One way to achieve this is to train models to learn distributions over weights in the layers and over the output. This can be achieved by using TenssorFlow probability (see the [documentation](https://www.tensorflow.org/probability) for an in-depth description of all the functionalities). In this example we will only scratch the surface of the capabilities that a probabilistic deep learning approach has to offer, by addressing only model uncertainty.
#
# To start with, think about a BNN as an extension of your classical DNN, where during training instead of learning a weights for each 'connection' in the network, we ask the model to lean a distribution. After model training, during inference time, we sample from the learned distributions to obtain the weights used in the model in the forward pass. The modifications that we have to implement in our `build_DNN` function are the following:
# - Substitute the hidden `Dense` layers with [`DenseVariational`](https://www.tensorflow.org/probability/api_docs/python/tfp/layers/DenseVariational) layers (this can be found under tensorflow-probability.layers). Do not forget to specify the `kl_weight` as 1/ number of iterations per epoch ([reference](https://arxiv.org/abs/1505.05424)).
# - Define the prior weights distribution (`make_prior_fn` input in the `DenseVariational`): this is the distribution that we expect the weights to have prior having seen the data. In this example we will not train the prior distribution.
# - Define the posterior weights distribution (`make_posterior_fn` input in the `DenseVariational`): this is the distribution that we expect the model to learn during training. Since we do not know at priory which is the posterior distribution, we let it be very general (i.e. multivariate Gaussian distribution) which parameters are learned by the model.
#
# You will find the `BNN_prior` and `BNN_posterior` defined for you in the `utilities.py` file. Update the `build_DNN` to accept a new boolean input `use_variational_layer` that when true substitutes the hidden `Dense` layers with the `DenseVariational` layers.
#
# **!NOTE** As you will see, training the BNN model is more computationally demanding and is more prone to over-fitting. Reduce the learning rate and increase the number of epochs to address this issue.
#
# #### **<span style="color:red">Questions</span>**
# 17. (MC dropout) What is the mean and the standard deviation of the test accuracy after evaluating the model on 100 times?
# 18. (CV) What is the mean and the standard deviation of the test accuracy?
# 19. (CV) What is the main advantage of dropout compared to CV for estimating test uncertainty? The difference may not be so large in this notebook, but imagine that you have a network that takes 24 hours to train.
# 20. (BNN) Build the BNN model and look at the number of parameters. Is there a difference between the previous DNN and the BNN? Why is that?
# 21. (BNN) Without training the model, evaluate the model a twice on the validation set: do you obtain the same validation accuracy? Why
# 22. Think of at least one advantage and one disadvantage for each of the three uncertainty estimation methods.
#
#
# #### **<span style="color:green">Answer</span>**
# 17. 0.91977683 mean and 0.0004742 std.
# 18. array([0.89395243, 0.89381391, 0.91375172, 0.91786242, 0.84052837,
#        0.9147678 , 0.84052593, 0.84052593, 0.84052593, 0.84052593]) Very bad generalization! 0.8736780345439911 mean and 0.033 std.
# 19. 100 forward passes is cheaper computationally than training 10 models for 24 hours. Cross validation might get a better estimate but since dropout can increase the sample size of the estimated test accuracy it will win out.
# 20. The BNN has way more parameters, it has a mean and std for each weight.
# 21. 0.4946039617061615 and 0.5047417283058167 accuracy, basically 50%. The network is above the descision boundary of 0.5 (at x = 0 the sigmoid is 0.5) 50% of the time, given the correct class we will guess it correct 50% of the time.
# 22.

# %%
np.random.seed(123)
Xtrain, Xtemp, Ytrain, Ytemp = train_test_split(X, Y, test_size=0.3)

mu, sd = compute_robust_params(Xtrain)
Xtrain = apply_robust_scaling(Xtrain, mu, sd, clipping = 5)
Xval, Xtest, Yval, Ytest = train_test_split(Xtemp, Ytemp, test_size=0.5)

Xval = apply_robust_scaling(Xval, mu, sd, clipping = 5)
Xtest = apply_robust_scaling(Xtest, mu, sd, clipping = 5)

# %%
class_weights
# Out:
# {0: np.float64(3.13725087684313), 1: np.float64(0.5947956837156341)}

# %%
# --------------------------------------------
# === Your code here =========================
# --------------------------------------------

# Your best training parameters
batch_size = 10000
epochs = 50
input_shape = (92,)
learning_rate = 0.3

tf.keras.losses.BinaryFocalCrossentropy(gamma = 0, label_smoothing=0.02)

np.random.seed(123)

value1, value2 = class_weight.compute_class_weight(class_weight="balanced", classes=np.unique(Ytrain), y= Ytrain)
class_weights = {0: value1*10000,
                1: value2}


max_lr = 1.5
warmup_duration = round(epochs*0.2)
# cosine annealing, one cycle
#https://wiki.cloudfactory.com/docs/mp-wiki/scheduler/cosineannealinglr
def scheduler(epoch, lr):
    if epoch < warmup_duration:
        return learning_rate + epoch * (max_lr-learning_rate) / warmup_duration
    else:
        decay_duration = epochs - warmup_duration
        epochs_past_warmup = epoch - warmup_duration
        min_lr = learning_rate * 0.1 

        progress = epochs_past_warmup / decay_duration
        cosine_multiplier = 0.5 * (1 + math.cos(math.pi * progress))
        
        return min_lr + (max_lr - min_lr) * cosine_multiplier    
    
callback = LearningRateScheduler(scheduler)

# using a setup closer to the automatic hyper params with 1 and 25
model11 = build_DNN(input_shape, 2, 5, loss, act_fun='sigmoid', optimizer='adam', learning_rate=learning_rate, print_summary=True, 
                    use_bn=False, use_custom_dropout=False, use_variational_layer=True, kl_weight = batch_size/Xtrain.shape[0])

#print(model11.evaluate(Xval, Yval, verbose=0))
#print(model11.evaluate(Xval, Yval, verbose=0))

""""
history11 =  model11.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights, 
                            callbacks=[callback])
"""

# ============================================
# Out:
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_variational_84 (Dens  (None, 5)                 108810
#  eVariational)
#
#  dense_variational_85 (Dens  (None, 5)                 495
#  eVariational)
#
#  dense_variational_86 (Dens  (None, 1)                 27
#  eVariational)
#
# =================================================================
# Total params: 109332 (427.08 KB)
# Trainable params: 109332 (427.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# '"\nhistory11 =  model11.fit(Xtrain, Ytrain, validation_data = (Xval, Yval), epochs = epochs, batch_size = batch_size, class_weight = class_weights, \n                            callbacks=[callback])\n'

# %%
# Out:
# [1.5364375114440918, 0.4946039617061615]
# [1.5183396339416504, 0.5047417283058167]

# %%
# Plot the history from the training run
plot_results(history11, lrbool = True)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# 1. Get the raw probabilities
ypred_probs = model.predict(Xtest)

# 2. Convert probabilities to class indices (0, 1, 2, etc.)
ypred_classes = np.argmax(ypred_probs, axis=1)

# 3. If Ytest is one-hot encoded, convert it back to indices too
ytrue_classes = Ytest
# Out:
# 3582/3582 [==============================] - 10s 3ms/step

# %%
# 4. Print the breakdown
print("Confusion Matrix:")
print(confusion_matrix(ytrue_classes, ypred_classes))

print("\nClassification Report:")
print(classification_report(ytrue_classes, ypred_classes))
# Out:
# Confusion Matrix:
# [[18040     0]
#  [96581     0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.16      1.00      0.27     18040
#            1       0.00      0.00      0.00     96581
#
#     accuracy                           0.16    114621
#    macro avg       0.08      0.50      0.14    114621
# weighted avg       0.02      0.16      0.04    114621
# c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\arone\Desktop\DeepLearning\deeplearninglabs\2_DNN\2_DNN\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# As we have done for the MC dropout uncertainty estimation, run the evaluation on the test set 100 times and show the mean and standard deviation.

# %%
# ============================================
# === Your code here =========================
# ============================================
# Run the testing 100 times, and save the accuracies in an array

n_runs = 100
score = np.array([model11.evaluate(Xtest, Ytest, verbose=0) for i in range(n_runs)])

# Calculate and print mean and std of accuracies
print(score.mean(axis = 0))
print(score.std(axis = 0))
# left is loss, right is accuracy.
score

# %% [markdown]
# # Part 5: DNN for regression
#
# A similar DNN can be used for regression, instead of classification.
#
# #### **<span style="color:red">Questions</span>**
# 23. How would you change the DNN used in this lab in order to use it for regression instead?
#
# #### **<span style="color:green">Answer</span>**
# Keep the clipping, MSE sc

# %% [markdown]
# ## Report
#
# Send in this jupyter notebook, with answers to all questions.
